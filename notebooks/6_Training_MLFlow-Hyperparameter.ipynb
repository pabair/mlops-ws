# %%
import pandas as pd

# %% [markdown]
# ## Trainingsdaten laden

# %%
train_df = pd.read_csv("../data/train.csv")
train_df.head()
# Out:
#    transactionId                 basket customerType  totalAmount  returnLabel
# 0     9534310106              [4, 3, 4]          new        252.0            1
# 1     7202594767        [4, 2, 0, 2, 5]     existing         70.0            0
# 2     2737331698                    [5]     existing         84.0            0
# 3     4868011733           [1, 4, 2, 4]     existing        116.0            0
# 4     7622406570  [2, 5, 3, 2, 3, 2, 0]     existing        378.0            0

# %% [markdown]
# ## Feature Engineering

# %%
def create_features(data_frame):
    data_frame = pd.get_dummies(data_frame, columns=["customerType"], dtype=int, drop_first=True)
    data_frame["orderedBooks"] = data_frame["basket"].apply(lambda x: sum(c.isdigit() for c in x))
    return data_frame

train_df = create_features(train_df)
train_df.head()
# Out:
#    transactionId                 basket  totalAmount  returnLabel  \
# 0     9534310106              [4, 3, 4]        252.0            1
# 1     7202594767        [4, 2, 0, 2, 5]         70.0            0
# 2     2737331698                    [5]         84.0            0
# 3     4868011733           [1, 4, 2, 4]        116.0            0
# 4     7622406570  [2, 5, 3, 2, 3, 2, 0]        378.0            0
#
#    customerType_new  orderedBooks
# 0                 1             3
# 1                 0             5
# 2                 0             1
# 3                 0             4
# 4                 0             7

# %% [markdown]
# ## Daten skalieren

# %%
from sklearn.preprocessing import StandardScaler

features = ["totalAmount", "orderedBooks"]
scaler = StandardScaler()
train_df[features] = scaler.fit_transform(train_df[features])
train_df.head()
# Out:
#    transactionId                 basket  totalAmount  returnLabel  \
# 0     9534310106              [4, 3, 4]    -0.032823            1
# 1     7202594767        [4, 2, 0, 2, 5]    -0.879459            0
# 2     2737331698                    [5]    -0.814334            0
# 3     4868011733           [1, 4, 2, 4]    -0.665475            0
# 4     7622406570  [2, 5, 3, 2, 3, 2, 0]     0.553309            0
#
#    customerType_new  orderedBooks
# 0                 1     -0.607275
# 1                 0      0.133204
# 2                 0     -1.347754
# 3                 0     -0.237036
# 4                 0      0.873682

# %%
X_train = train_df.drop(columns=["returnLabel", "transactionId", "basket"])
y_train = train_df["returnLabel"]

# %%
from sklearn.ensemble import RandomForestClassifier

param_grid = {
    "n_estimators": [50, 100, 200],
    "max_depth": [5, 10, 20, 100],
    "min_samples_split": [2, 5, 10]
}

# %%
from sklearn.model_selection import ParameterGrid

grid = list(ParameterGrid(param_grid))
grid[:5]
# Out:
# [{'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 50},
#  {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 100},
#  {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 200},
#  {'max_depth': 5, 'min_samples_split': 5, 'n_estimators': 50},
#  {'max_depth': 5, 'min_samples_split': 5, 'n_estimators': 100}]

# %% [markdown]
# ## Modell auf Testdaten anwenden

# %%
test_df = pd.read_csv("../data/test.csv")
test_df.head()
# Out:
#    transactionId                             basket customerType  totalAmount  \
# 0     4132523932                 [4, 3, 4, 3, 2, 3]     existing        366.0
# 1     8998574539                    [3, 4, 4, 3, 5]     existing         85.0
# 2     9346688547  [1, 1, 2, 2, 4, 4, 3, 1, 1, 0, 3]     existing        275.0
# 3     4533897707           [3, 2, 2, 1, 5, 1, 1, 0]     existing        528.0
# 4     3334800500              [4, 2, 3, 5, 2, 5, 1]     existing        287.0
#
#    returnLabel
# 0            1
# 1            0
# 2            0
# 3            0
# 4            0

# %%
test_df = create_features(test_df)
test_df.head()
# Out:
#    transactionId                             basket  totalAmount  returnLabel  \
# 0     4132523932                 [4, 3, 4, 3, 2, 3]        366.0            1
# 1     8998574539                    [3, 4, 4, 3, 5]         85.0            0
# 2     9346688547  [1, 1, 2, 2, 4, 4, 3, 1, 1, 0, 3]        275.0            0
# 3     4533897707           [3, 2, 2, 1, 5, 1, 1, 0]        528.0            0
# 4     3334800500              [4, 2, 3, 5, 2, 5, 1]        287.0            0
#
#    customerType_new  orderedBooks
# 0                 0             6
# 1                 0             5
# 2                 0            11
# 3                 0             8
# 4                 0             7

# %%
features = ["totalAmount", "orderedBooks"] 
test_df[features] = scaler.transform(test_df[features])
test_df.head()
# Out:
#    transactionId                             basket  totalAmount  returnLabel  \
# 0     4132523932                 [4, 3, 4, 3, 2, 3]     0.497487            1
# 1     8998574539                    [3, 4, 4, 3, 5]    -0.809682            0
# 2     9346688547  [1, 1, 2, 2, 4, 4, 3, 1, 1, 0, 3]     0.074169            0
# 3     4533897707           [3, 2, 2, 1, 5, 1, 1, 0]     1.251086            0
# 4     3334800500              [4, 2, 3, 5, 2, 5, 1]     0.129991            0
#
#    customerType_new  orderedBooks
# 0                 0      0.503443
# 1                 0      0.133204
# 2                 0      2.354640
# 3                 0      1.243922
# 4                 0      0.873682

# %%
X_test = test_df.drop(["transactionId", "returnLabel", "basket"], axis=1)
y_test = test_df["returnLabel"]

# %% [markdown]
# ## MLFlow Part

# %%
import mlflow
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score
from mlflow.models import infer_signature
from mlflow import MlflowClient

mlflow.set_tracking_uri(uri="http://localhost:8080")
mlflow.set_experiment("MLflow Return Data HyperParamTuning")

client = MlflowClient()

for params in grid:
    with mlflow.start_run():

        mlflow.set_tag("Training Info", "Basic RF model for return data")
        
        rf = RandomForestClassifier(**params)
        rf.fit(X_train, y_train)

        predictions = rf.predict(X_test)

        accuracy = accuracy_score(y_test, predictions)
        precision = precision_score(y_test, predictions)
        recall = recall_score(y_test, predictions)
        
        # Log theparameters and tags
        mlflow.log_params(params)
        
        # Log the loss metric
        mlflow.log_metric("accuracy", accuracy)
        mlflow.log_metric("precision", precision)
        mlflow.log_metric("recall", recall)

print("done.")
# Out:
# 2025/10/30 11:41:13 INFO mlflow.tracking.fluent: Experiment with name 'MLflow Return Data HyperParamTuning' does not exist. Creating a new experiment.
# 🏃 View run agreeable-croc-680 at: http://localhost:8080/#/experiments/271063554503179368/runs/66eaad751a984305a5bb6bc5fa18fd0d
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run sincere-mouse-857 at: http://localhost:8080/#/experiments/271063554503179368/runs/b9c00d7015e44ba897329861bad5de22
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run burly-conch-183 at: http://localhost:8080/#/experiments/271063554503179368/runs/16645200a40946c3a438c516532ed837
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run defiant-pug-627 at: http://localhost:8080/#/experiments/271063554503179368/runs/1423b69fbfa34f1db4a942b0330e03a6
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run invincible-steed-631 at: http://localhost:8080/#/experiments/271063554503179368/runs/bde4087e80764a6aa952d897dcbc23b2
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run merciful-ray-629 at: http://localhost:8080/#/experiments/271063554503179368/runs/6cc488fd341540218a55a2ddb0bd2a8d
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run vaunted-hawk-19 at: http://localhost:8080/#/experiments/271063554503179368/runs/8ffd65d990154e33aa1283553909ddc5
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run delicate-deer-529 at: http://localhost:8080/#/experiments/271063554503179368/runs/33044b43a0894970be4ab4f0b8ef965c
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run exultant-auk-25 at: http://localhost:8080/#/experiments/271063554503179368/runs/885726df02054d199a940c41e1e21e26
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run clumsy-elk-673 at: http://localhost:8080/#/experiments/271063554503179368/runs/0c5191756e7f4839891a3a0bb4a717d5
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run big-calf-906 at: http://localhost:8080/#/experiments/271063554503179368/runs/45d8fa3d496d46f8890a96217644bb97
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run grandiose-wolf-645 at: http://localhost:8080/#/experiments/271063554503179368/runs/0a39d8e4e925459a83b6efe794bf8cc7
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run welcoming-bee-45 at: http://localhost:8080/#/experiments/271063554503179368/runs/7b9e30bfaa0b4ff2aef92a81e1543e9a
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run nebulous-hen-639 at: http://localhost:8080/#/experiments/271063554503179368/runs/8c64f12363fe4da6968aad2323b235bf
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run intelligent-tern-972 at: http://localhost:8080/#/experiments/271063554503179368/runs/353f03773fcc46cbbea9732de3c52fe4
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run upset-wren-63 at: http://localhost:8080/#/experiments/271063554503179368/runs/7bcef4736fbe4e1291dc4e88a3c7f533
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run angry-wolf-322 at: http://localhost:8080/#/experiments/271063554503179368/runs/c7a894f06db442c1a0a3dc13affd2ed0
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run amazing-smelt-611 at: http://localhost:8080/#/experiments/271063554503179368/runs/104f1f7d35994310af2737a79a6e0e24
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run blushing-grub-185 at: http://localhost:8080/#/experiments/271063554503179368/runs/28f0883d08ff4dceaca3a308e17a987e
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run dazzling-fish-398 at: http://localhost:8080/#/experiments/271063554503179368/runs/5cda63ce02294f3ea7985028e0c04568
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run calm-cat-65 at: http://localhost:8080/#/experiments/271063554503179368/runs/beffd340232a48afb1e3c062650e7e76
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run marvelous-panda-134 at: http://localhost:8080/#/experiments/271063554503179368/runs/461f5291960640b9b075168225f9364f
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run secretive-snipe-352 at: http://localhost:8080/#/experiments/271063554503179368/runs/a1cb680256844bffaf3a33514907b6dc
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run luminous-moth-907 at: http://localhost:8080/#/experiments/271063554503179368/runs/c1caf5f53f0046ecb385453376662886
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run sassy-hen-103 at: http://localhost:8080/#/experiments/271063554503179368/runs/0b4c450944a74a60931d249860a647e0
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run unique-steed-834 at: http://localhost:8080/#/experiments/271063554503179368/runs/753315784be245fa9bb2d19614a55237
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run bold-croc-663 at: http://localhost:8080/#/experiments/271063554503179368/runs/d00ae8ce2d5643bcaa9f29b4c5931e14
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run clumsy-horse-753 at: http://localhost:8080/#/experiments/271063554503179368/runs/d1f7535c6fff4d74bb38df429357b6ac
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run dashing-sow-487 at: http://localhost:8080/#/experiments/271063554503179368/runs/1d8984e64ecb42ae96040cb23fc2c421
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run suave-donkey-665 at: http://localhost:8080/#/experiments/271063554503179368/runs/c824c1fe15c34bbf87e201240707175d
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run auspicious-rat-105 at: http://localhost:8080/#/experiments/271063554503179368/runs/0a58573f38d3479cae98ee7189213cac
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run able-penguin-458 at: http://localhost:8080/#/experiments/271063554503179368/runs/ca8d4bdc8ab844b884bdd96f135a8c7e
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run smiling-pug-349 at: http://localhost:8080/#/experiments/271063554503179368/runs/2027ef9f2f564bae9e8421c4ef377fbd
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run melodic-squid-165 at: http://localhost:8080/#/experiments/271063554503179368/runs/659c3054f5c7449d9c751ab15783e6c1
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run useful-whale-815 at: http://localhost:8080/#/experiments/271063554503179368/runs/3c987eaef1b14581a971fda9371bc463
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
# 🏃 View run thundering-midge-165 at: http://localhost:8080/#/experiments/271063554503179368/runs/64a34f9393444644afc8d9761dbcdc52
# 🧪 View experiment at: http://localhost:8080/#/experiments/271063554503179368
